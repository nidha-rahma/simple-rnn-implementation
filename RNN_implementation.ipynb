# %% [markdown]
# <a href="https://colab.research.google.com/github/nidha-rahma/simple-rnn-implementation/blob/main/RNN_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Choose the path to your CSV in Drive
CSV_PATH = "/content/drive/MyDrive/airline_passengers.csv"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
df = pd.read_csv(CSV_PATH)
print("First 5 rows:")
display(df.head())
# Out:
# First 5 rows:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
data = df["Passengers"].values.reshape(-1,1)
plt.figure(figsize=(10,4))
plt.plot(data, label='Passengers')
plt.title("Monthly Airline Passengers")
plt.xlabel("Time (months)")
plt.ylabel("Passengers")
plt.legend()
plt.show()

# %%
# 2. Normalize data
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(data)

# %%
# 3. Create sequences (look_back = 10 months)
def create_dataset(series, look_back=10):
    X, y = [], []
    for i in range(len(series)-look_back):
        X.append(series[i:i+look_back, 0])
        y.append(series[i+look_back, 0])
    return np.array(X), np.array(y)

look_back = 10
X, y = create_dataset(scaled, look_back)
X = X.reshape((X.shape[0], look_back, 1))  # (samples, timesteps, features)

# %%
# 4. Split train/test
split = int(len(X)*0.67)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
# 5. Build simple Vanilla RNN
model = keras.Sequential([
    layers.SimpleRNN(16, input_shape=(look_back,1), activation="tanh"),
    layers.Dense(1)
])
model.compile(optimizer="adam", loss="mse")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 6. Train
history = model.fit(X_train, y_train, epochs=50, batch_size=12, verbose=1)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0203
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0190
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0181
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0206
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0198
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0192
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0198
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0201
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0195
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0188
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0213
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0178
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0191
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0188
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0194
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0189
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0201
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0201
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0195
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0200
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0203
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0194
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0190
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0190
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0194
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0175
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0193
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0199
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0178
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0190
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0179
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0194
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0198
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0201
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0191
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0166
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0182
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0207
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0188
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0205
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0187
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0201
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0179
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0185
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0179
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0177
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0179
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0158
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0176
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0192

# %%
# 7. Predict
pred = model.predict(X_test)
pred_rescaled = scaler.inverse_transform(pred)
y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
# 8. Plot results
plt.plot(y_test_rescaled, label="Actual")
plt.plot(pred_rescaled, label="Predicted")
plt.title("Simple Vanilla RNN Forecast")
plt.legend()
plt.show()
